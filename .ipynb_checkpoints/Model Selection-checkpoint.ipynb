# %% [markdown]
# # Model Selection
#
# ## Here, we discuss the feature selection of our model.

# %%
pip install xlrd
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 2.5 MB/s eta 0:00:00
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd

'''
banco.query('PD04682MD') # Daily interest rate of deposits in PEN, "instantaneous" spot of the yield / ... Multicolinear with tc?
banco.query('PD04701XD') # Daily price for the copper. Exogenous factor.
banco.query('PD04709XD') # EMBIG Spread, country risk indicator. Endogenous factor. Independant?
banco.query('PD04643PD') # USDPEN 11 AM Buy
banco.query('PD04644PD') # USDPEN 11 AM Bid
banco.query('PD04645PD') # USDPEN 01:30 PM Buy
banco.query('PD04646PD') # USDPEN 01:30 PM Bid
'''

series_codes = ['PD04682MD', 'PD04701XD', 'PD04709XD', 'PD04643PD', 'PD04644PD', 'PD04645PD', 'PD04646PD']

start_date = '2004-02-01'
end_date = '2024-10-01'

# Construct the URL
url = f"https://estadisticas.bcrp.gob.pe/estadisticas/series/api/{'-'.join(series_codes)}/txt/{start_date}/{end_date}"

response = requests.get(url)

with open("economic_data.txt", "wb") as file:
    file.write(response.content)

# %%
# Read the data
df = pd.read_csv("economic_data.txt", sep="\t", na_values=["n.d."])

# Strip whitespace from the column names
df.columns = df.columns.str.strip()

# Replace Spanish month abbreviations in the date column
df['Día/Mes/Año'] = df['Día/Mes/Año'].apply(replace_spanish_months)

# Convert the date column to datetime format
df['Día/Mes/Año'] = pd.to_datetime(df['Día/Mes/Año'], format='%d.%b.%y', dayfirst=True)

# Reset the index to flatten the DataFrame
df.reset_index(drop=True, inplace=True)

# Clean the column names again if necessary
df.columns = df.columns.str.strip()

# Display the cleaned DataFrame
print("\nProcessed Data:")
print(df)
df.to_csv("economic_data_cleaned.csv", index=False)
# Out:
# Processed Data:
#      Día/Mes/Año Tipo de cambio - TC 11:00 AM (S/ por US$) - Compra  \
# 0     2004-02-02                                            3.5055
# 1     2004-02-03                                            3.4966
# 2     2004-02-04                                             3.493
# 3     2004-02-05                                             3.493
# 4     2004-02-06                                            3.4913
# ...          ...                                                ...
# 5387  2024-09-25                                             3.769
# 5388  2024-09-26                                             3.728
# 5389  2024-09-27                                             3.713
# 5390  2024-09-30                                             3.705
# 5391  2024-10-01                                             3.713
#
#      Tipo de cambio - TC 11:00 AM (S/ por US$) - Venta  \
# 0                                              3.5075
# 1                                               3.497
# 2                                              3.4935
# 3                                              3.4933
# 4                                              3.4914
# ...                                                ...
# 5387                                             3.77
# 5388                                            3.729
# 5389                                            3.716
# 5390                                            3.707
# 5391                                            3.714
#
#      Tipo de cambio - TC Cierre Compra - 01:30 PM (S/ por US$)  \
# 0                                               3.5015
# 1                                               3.4965
# 2                                                3.489
# 3                                               3.4931
# 4                                                3.492
# ...                                                 ...
# 5387                                             3.748
# 5388                                             3.723
# 5389                                             3.711
# 5390                                             3.703
# 5391                                             3.718
#
#      Tipo de cambio - TC Cierre Venta - 01:30 PM (S/ por US$)  \
# 0                                                3.502
# 1                                                3.497
# 2                                                 3.49
# 3                                                3.494
# 4                                               3.4925
# ...                                                 ...
# 5387                                             3.749
# 5388                                             3.726
# 5389                                             3.714
# 5390                                             3.705
# 5391                                              3.72
#
#      Tasas de interés - Operaciones de reporte, total  \
# 0                                   2.53571428571429
# 1                                          2.5278125
# 2                                   2.52675675675676
# 3                                   2.52847170450695
# 4                                               2.54
# ...                                               ...
# 5387                                5.13646366393204
# 5388                                4.96623289872083
# 5389                                4.92571559103769
# 5390                                4.97267526023738
# 5391                                 5.0503237822208
#
#      Cotizaciones internacionales - Cobre (Londres, cUS$ por libras)  \
# 0                                             115.2125
# 1                                             115.5527
# 2                                             116.9134
# 3                                             117.4351
# 4                                             116.7093
# ...                                                 ...
# 5387                                  436.287825408303
# 5388                                  446.516333453172
# 5389                                  447.242081252365
# 5390                                  443.023672169559
# 5391                                  441.844331995871
#
#       Tasas de interés: EMBIG (variación en pbs) - Spread - EMBIG Perú (pbs)
# 0                                                   397
# 1                                                   379
# 2                                                   371
# 3                                                   377
# 4                                                   365
# ...                                                 ...
# 5387                                                155
# 5388                                                156
# 5389                                                156
# 5390                                                154
# 5391                                                154
#
# [5392 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.set_index('Día/Mes/Año', inplace=True)

# Plotting the data
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Tipo de cambio - TC 11:00 AM (S/ por US$) - Compra'], marker='o', label='Compra', color='blue')
plt.plot(df.index, df['Tipo de cambio - TC 11:00 AM (S/ por US$) - Venta'], marker='o', label='Venta', color='red')

# Adding titles and labels
plt.title('Tipo de Cambio - Compra y Venta (S/ por US$)', fontsize=16)
plt.xlabel('Fecha', fontsize=14)
plt.ylabel('Tipo de Cambio (S/ por US$)', fontsize=14)
plt.xticks(rotation=45)  # Rotate date labels for better readability
plt.legend()
plt.tight_layout()

# Show the plot
plt.show()
